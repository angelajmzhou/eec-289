# %%
from scipy.io import loadmat
import numpy as np

import requests
import tarfile

from pathlib import Path
import re
import shutil
from tqdm import tqdm
import torch
import torch.nn as nn
import torchvision.transforms as T
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader, TensorDataset
from torchvision.models import resnet18, ResNet18_Weights
from torchvision.io import decode_image
from torch.utils.data import Dataset
from torchinfo import summary
import os
from matplotlib import pyplot as plt

import math
from dataclasses import dataclass

import torch.nn.functional as F



device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
# define directory names
root_dir = './data'
src_dir = './data/jpg' # this is just where i have all the pics
train_dir = './data/train'
val_dir = './data/val'
test_dir = './data/test'

# %% [markdown]
# ## Data splits

# %%
def download_file(url, download_path):
    # Download the file with streaming to handle large files efficiently
    print(f"Downloading from: {url}")
    try:
        with requests.get(url, stream=True) as r:
            r.raise_for_status() # Raise an exception for bad status codes
            with open(download_path, 'wb') as f:
                shutil.copyfileobj(r.raw, f)
        print(f"Download complete: {download_path}")
    except requests.exceptions.RequestException as e:
        print(f"Download failed: {e}")
    except Exception as e:
        print(f"An unexpected error occurred: {e}")

def download_and_extract_tgz(url, download_path, extract_path):
    # 1. Ensure the extract directory exists
    os.makedirs(extract_path, exist_ok=True)
    print(f"Ensured extraction directory exists: {extract_path}")

    # 2. Download the file with streaming to handle large files efficiently
    print(f"Downloading from: {url}")
    try:
        with requests.get(url, stream=True) as r:
            r.raise_for_status() # Raise an exception for bad status codes
            with open(download_path, 'wb') as f:
                shutil.copyfileobj(r.raw, f)
        print(f"Download complete: {download_path}")

        # 3. Extract the .tgz file
        print(f"Extracting to: {extract_path}")
        with tarfile.open(download_path, 'r:gz') as tar_file:
            tar_file.extractall(path=extract_path)
        print("Extraction complete.")

    except requests.exceptions.RequestException as e:
        print(f"Download failed: {e}")
    except tarfile.TarError as e:
        print(f"Extraction failed: {e}")
    except Exception as e:
        print(f"An unexpected error occurred: {e}")
    finally:
        # Optional: Remove the downloaded .tgz file after extraction
        if os.path.exists(download_path):
            os.remove(download_path)
            print(f"Removed temporary download file: {download_path}")

# %%
# download dataset:
dataset_url = 'https://www.robots.ox.ac.uk/~vgg/data/flowers/102/102flowers.tgz'
temp_file_name = 'images.tgz'
destination_folder = './data'
download_and_extract_tgz(dataset_url, temp_file_name, destination_folder)

# download metadata files
metadata_files = [('https://www.robots.ox.ac.uk/~vgg/data/flowers/102/imagelabels.mat','./data/imagelabels.mat'),
                  ('https://www.robots.ox.ac.uk/~vgg/data/flowers/102/setid.mat', './data/setid.mat')
                  ]

for url, file in metadata_files:
    download_file(url, file)
# Out:
# Ensured extraction directory exists: ./data
# Downloading from: https://www.robots.ox.ac.uk/~vgg/data/flowers/102/102flowers.tgz
# Download complete: images.tgz
# Extracting to: ./data
# Extraction complete.
# Removed temporary download file: images.tgz
# Downloading from: https://www.robots.ox.ac.uk/~vgg/data/flowers/102/imagelabels.mat
# Download complete: ./data/imagelabels.mat
# Downloading from: https://www.robots.ox.ac.uk/~vgg/data/flowers/102/setid.mat
# Download complete: ./data/setid.mat

# %%
def ensure_split_folder(split_dir, split_ids, labels, source_dir="./data/jpg"):
    source_path = Path(source_dir)
    target_path = Path(split_dir)

    if target_path.exists():
        print(f"{target_path} already exists; skipping creation.")
        return target_path

    target_path.mkdir(parents=True, exist_ok=True)
    split_id_set = set(np.asarray(split_ids).reshape(-1).astype(int).tolist())
    labels_arr = np.asarray(labels).reshape(-1).astype(int)

    copied = 0
    for file_path in tqdm(source_path.iterdir()):
        if not file_path.is_file():
            continue

        match = re.search(r"(\d+)(?!.*\d)", file_path.stem)
        if not match:
            continue

        sample_id = int(match.group(1))
        if sample_id not in split_id_set:
            continue

        label = int(labels_arr[sample_id - 1])
        label_dir = target_path / str(label)
        label_dir.mkdir(parents=True, exist_ok=True)

        shutil.copy2(file_path, label_dir / file_path.name)
        copied += 1

    print(f"Created {target_path} with {copied} files.")
    return target_path

# %%
# define directory names
root_dir = './data'
src_dir = './data/jpg' # this is just where i have all the pics
train_dir = './data/train'
val_dir = './data/val'
test_dir = './data/test'

# load in set splits
# it looks like the train and test set ids are swapped for some reason? 
# test has 6000 examples, and train only has 1000 (same as val)
# swap these here so that we actually train on training data
setid = loadmat("./data/setid.mat")
labels = loadmat("./data/imagelabels.mat")['labels']
test = setid['trnid']
val = setid['valid']
train = setid['tstid']

# split data into train, val, test
# we just copyin for now since the dataset is so small
ensure_split_folder(train_dir, train, labels)
ensure_split_folder(val_dir, val, labels)
ensure_split_folder(test_dir, test, labels)
# Out:
# data/train already exists; skipping creation.
# data/val already exists; skipping creation.
# data/test already exists; skipping creation.
# PosixPath('data/test')

# %%
print(setid['trnid'].shape)
print(setid['tstid'].shape)
print(setid['valid'].shape)
# Out:
# (1, 1020)
# (1, 6149)
# (1, 1020)

# %% [markdown]
# ## DataLoader definitions

# %%
mean = [0.485, 0.456, 0.406]
std  = [0.229, 0.224, 0.225]

# %%
# dataset is small and can be loaded onto gpu, so do that to speed up training
def make_gpu_dataset(directory: Path, transform, two_view: bool = True):
    dataset = ImageFolder(
        root=directory,
        transform=transform
        )
    
    all_images = []
    all_labels = []

    # Iterate through the dataset and collect all items (this may take time)
    for i in tqdm(range(len(dataset))):
        if two_view:
            (view1, view2), label = dataset[i]
            views = torch.stack((view1, view2))
        else:
            views, label = dataset[i]
        all_images.append(views)
        all_labels.append(label)
    # Stack the list of tensors into single large tensors
    # Use torch.stack to combine the list of individual image tensors
    images_tensor = torch.stack(all_images)
    labels_tensor = torch.tensor(all_labels)

    # Move the entire tensors to the specified device (GPU)
    images_gpu = images_tensor.to(device)
    labels_gpu = labels_tensor.to(device)

    print(f"Dataset loaded to GPU. Images shape: {images_gpu.shape}, Labels shape: {labels_gpu.shape}")

    # Wrap the GPU tensors in a TensorDataset
    gpu_dataset = TensorDataset(images_gpu, labels_gpu)

    # Create a DataLoader for batching (batch size can be large, limited by VRAM)
    return gpu_dataset

# %%
# two views for contrastive objective
class TwoViewTransform:
    def __init__(self, base_transform):
        self.base_transform = base_transform

    def __call__(self, x):
        view1 = self.base_transform(x)
        view2 = self.base_transform(x)
        return view1, view2
    
simclr_train_val_transform = T.Compose([
    T.RandomResizedCrop(224, scale=(0.6, 1.0)),
    T.RandomHorizontalFlip(),
    T.RandomApply(
        [T.ColorJitter(0.4, 0.4, 0.4, 0.1)],
        p=0.8
    ),
    #T.RandomGrayscale(p=0.2), # OG SimCLR doesnt use this
    T.GaussianBlur(kernel_size=23, sigma=(0.1, 2.0)),
    T.ToTensor(),
    T.Normalize(mean, std)
])
simclr_test_transform = T.Compose([T.RandomResizedCrop(224, scale=(0.6, 1.0)),
                                   T.ToTensor(),
                                   T.Normalize(mean, std)])

### ATTENTION ###
### if you don't want the added speed or need the GPU memory, set this to false
load_data_directly_onto_gpu = False
if load_data_directly_onto_gpu:    
    train_set = make_gpu_dataset(train_dir, TwoViewTransform(simclr_train_val_transform))
else:
    train_set = ImageFolder(
        root=train_dir,
        transform=TwoViewTransform(simclr_train_val_transform)
        )

# %%
train_loader = DataLoader(train_set, 
                          batch_size=512, 
                          shuffle=True, 
                          num_workers=8, 
                          drop_last=True)

# %%
def get_mae_dataloader(data_dir, batch_size=256, num_workers=8):
    dataset = ImageFolder(
        root=data_dir,
        transform=mae_transform
    )
    
    loader = DataLoader(
        dataset,
        batch_size=batch_size,
        shuffle=True,
        num_workers=num_workers,
        pin_memory=True,
    )
    
    return loader
    
mae_transform = T.Compose([
    T.RandomResizedCrop(224, scale=(0.2, 1.0), interpolation=3),
    T.RandomHorizontalFlip(),
    T.ToTensor(),
    T.Normalize(mean, std)
])

train_loader = get_mae_dataloader(train_dir)

# %% [markdown]
# ## SimCLR Model

# %%
class ConvBNReLU(nn.Module):
    def __init__(self, in_channels, out_channels, kernel_size=3, stride=1, padding=1):
        super().__init__()
        self.block = nn.Sequential(
            nn.Conv2d(
                in_channels,
                out_channels,
                kernel_size=kernel_size,
                stride=stride,
                padding=padding,
                bias=False,
            ),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True),
        )

    def forward(self, x):
        return self.block(x)


class ResidualBlock(nn.Module):
    def __init__(self, channels):
        super().__init__()
        self.block = nn.Sequential(
            ConvBNReLU(channels, channels, kernel_size=3, stride=1, padding=1),
            nn.Conv2d(channels, channels, kernel_size=3, stride=1, padding=1, bias=False),
            nn.BatchNorm2d(channels),
        )
        self.relu = nn.ReLU(inplace=True)

    def forward(self, x):
        out = self.block(x)
        out = out + x
        return self.relu(out)


class ResNet9Encoder(nn.Module):
    def __init__(self, in_channels=3, feat_dim=512):
        super().__init__()
        self.feat_dim = feat_dim
        self.stem = nn.Sequential(
            ConvBNReLU(in_channels, 32, 7, 2, 3),
            ConvBNReLU(32, 64, 3, 2, 1),
            nn.MaxPool2d(2),
        )
        self.res1 = ResidualBlock(64)

        self.mid = nn.Sequential(
            ConvBNReLU(64, 128, 3, 1, 1),
            nn.MaxPool2d(2),
            ConvBNReLU(128, 256, 3, 1, 1),
            nn.MaxPool2d(2),
        )
        self.res2 = ResidualBlock(256)

        self.pool = nn.AdaptiveAvgPool2d(1)
        self.fc = nn.Linear(256, feat_dim)

    def forward(self, x):
        x = self.stem(x)
        x = self.res1(x)
        x = self.mid(x)
        x = self.res2(x)
        x = self.pool(x)
        x = torch.flatten(x, 1)
        x = self.fc(x)
        return x

class ResNet18Encoder(nn.Module):
    def __init__(self, freeze: bool = True, retrain_layer4: bool = True):
        super().__init__()

        if freeze:
            weights = ResNet18_Weights.DEFAULT
            self.resnet18 = resnet18(weights=weights)
        else:
            self.resnet18 = resnet18(weights=None)

        # replace last layer with linear projection head
        self.resnet18.fc = nn.Identity()

        if freeze:
            for param in self.resnet18.parameters():
                param.requires_grad = False
        
        if freeze and retrain_layer4:
            # Unfreeze the parameters in the last block (layer4)
            for param in self.resnet18.layer4.parameters():
                param.requires_grad = True

        # Unfreeze the parameters in the new fully connected layer (fc)
        for param in self.resnet18.fc.parameters():
            param.requires_grad = True
    
    def forward(self, x: torch.Tensor) -> torch.Tensor:
        return self.resnet18(x)

class SimCLR(nn.Module):
    def __init__(self, encoder: nn.Module, 
                 encoder_out_features: int, 
                 out_features=128):
        super().__init__()
        
        self.encoder = encoder

        # projection head
        self.projector = nn.Sequential(
            nn.Linear(encoder_out_features, 256),
            nn.ReLU(),
            nn.Linear(256, out_features)
        )      

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        y_pred = self.encoder(x)
        y_pred = self.projector(y_pred)
        return y_pred
    
    @torch.no_grad()
    def representation(self, x: torch.Tensor) -> torch.Tensor:
        return self.encoder(x)

# %% [markdown]
# ## NT-XENT loss function

# %%
import torch
import torch.nn.functional as F

def nt_xent_loss(z1: torch.Tensor, z2: torch.Tensor, temperature: float = 0.2) -> torch.Tensor:
    if z1.ndim != 2 or z2.ndim != 2:
        raise ValueError(f"z1 and z2 must be 2D (B,D). Got {z1.shape} and {z2.shape}.")
    if z1.shape != z2.shape:
        raise ValueError(f"z1 and z2 must have the same shape. Got {z1.shape} vs {z2.shape}.")

    B, D = z1.shape
    if B < 2:
        raise ValueError("Batch size must be >= 2 for contrastive loss (needs negatives).")

    # concatenate for a (2B, D) tensor
    z = torch.cat([z1, z2], dim=0)  # (2B, D)

    # cosine similarity
    sim = F.cosine_similarity(z[None,:,:], z[:,None,:], dim=-1)
    
    # mask self similarity
    sim[torch.eye(z.size(0)).bool()] = float("-inf")

    # positive indices:
    # For i in [0..B-1] (z1), positive is i+B (z2)
    # For i in [B..2B-1] (z2), positive is i-B (z1)
    pos_idx = torch.arange(2 * B, device=z.device)
    pos_idx = (pos_idx + B) % (2 * B)

    # cross-entropy loss where each anchor predicts its positive among 2B-1 candidates
    # Targets: for each row i, the positive is at column pos_idx[i]
    loss = F.cross_entropy(sim/temperature, pos_idx)

    return loss

# %% [markdown]
# ## Train SimCLR

# %%
def train_simCLR_model(model: nn.Module, 
                       train_loader: DataLoader, 
                       epochs: int, 
                       lr: float):
    model.to(device)
    opt = torch.optim.Adam(model.parameters(), lr=lr)
    results = {"train_loss": [], "val_loss": []}
    for ep in range(1, epochs + 1):
        running = 0.0
        n_batches = 0
        pbar = tqdm(train_loader, desc=f"epoch {ep}/{epochs}", leave=False)
        
        model.train()
        for sample in pbar:
            views, _ = sample
            if load_data_directly_onto_gpu:
                x1 = views[:,0,:,:,:] #list obj
                x2 = views[:,1,:,:,:]
            else:
                x1 = views[0].to(device)
                x2 = views[1].to(device)
            z1 = model(x1)
            z2 = model(x2)
        
            loss = nt_xent_loss(z1, z2)
            opt.zero_grad()
            loss.backward()
            opt.step()

            running += float(loss.item())
            n_batches += 1
            pbar.set_postfix(loss=running / n_batches)
        
        train_loss = running / max(1, n_batches)
        results["train_loss"].append(train_loss)
    
        if ep % 10 == 0:
            print(f"epoch {ep}: train_loss={train_loss:.4f}")
    results['model'] = model
    return results

# %%
encoder = ResNet9Encoder()
simCLR = SimCLR(encoder, 512)

lr = 1e-3
epochs = 100
results = train_simCLR_model(simCLR, train_loader, epochs, lr)
# Out:
# epoch 10: train_loss=3.4876
# epoch 20: train_loss=3.0922
# epoch 30: train_loss=2.9593
# epoch 40: train_loss=2.8704
# epoch 50: train_loss=2.7861
# epoch 60: train_loss=2.7316
# epoch 70: train_loss=2.6784
# epoch 80: train_loss=2.6641
# epoch 90: train_loss=2.6228
# epoch 92/100:   0%|                                      | 0/12 [00:00<?, ?it/s]

# %%
from matplotlib import pyplot as plt
plt.title("loss curve")
plt.plot(results['train_loss'])

# %% [markdown]
# # MAE

# %%
 import torch
import gc

# 1. Delete your model and optimizer objects
del mae_model
# del optimizer (if you have one)

# 2. Force Python's garbage collector to run
gc.collect()

# 3. Clear the PyTorch CUDA cache
torch.cuda.empty_cache()

# %%
# ------------------------------------------------------------
# Config
# ------------------------------------------------------------

@dataclass
class MAEConfig:
    img_size: int = 224
    patch_size: int = 16
    in_chans: int = 3

    enc_embed_dim: int = 384*2
    enc_depth: int = 16
    enc_num_heads: int = 12
    mlp_ratio: float = 4.0

    dec_embed_dim: int = 512
    dec_depth: int = 4
    dec_num_heads: int = 16

    mask_ratio: float = 0.80
    norm_pix_loss: bool = True


# ------------------------------------------------------------
# Helpers
# ------------------------------------------------------------
def denormalize(tensor):
    """
    Args: tensor [3, H, W]
    Returns: numpy array [H, W, 3] ready for plt.imshow
    """
    # Clone to avoid modifying the original tensor
    t = tensor.clone().cpu()
    
    # Reverse the normalization
    for i in range(3):
        t[i] = t[i] * std[i] + mean[i]
        
    # Clamp to [0, 1] range to avoid floating point errors
    t = torch.clamp(t, 0, 1)
    
    # [3, H, W] -> [H, W, 3]
    return t.permute(1, 2, 0).numpy()

@torch.no_grad()
def get_mae_features(mae_model, imgs):
    """
    Extracts the global CLS token features from the pre-trained MAE.
    imgs: [B, 3, 224, 224]
    returns: [B, enc_embed_dim]
    """
    # 1. Image -> Patches [B, L, D]
    x = mae_model.patch_embed(imgs)

    # 2. Add positional embeddings (Skip index 0, which is for CLS)
    x = x + mae_model.pos_embed_enc[:, 1:, :]

    # 3. Prepare and prepend CLS token
    # We add the 0th pos_embed so the transformer knows this is the "summary" slot
    cls_token = mae_model.cls_token + mae_model.pos_embed_enc[:, :1, :]
    cls_tokens = cls_token.expand(x.shape[0], -1, -1)
    x = torch.cat([cls_tokens, x], dim=1)

    # 4. Pass through the Transformer Blocks (Full Attention, No Masking)
    for blk in mae_model.encoder_blocks:
        x = blk(x)
    x = mae_model.enc_norm(x)

    # 5. Extract only the CLS token (the global representation)
    #return x[:, 0, :]
    return x[:, 1:, :].mean(dim=1)
def get_2d_sincos_pos_embed(embed_dim: int, grid_size: int, cls_token: bool = False):
    """
    Stub for fixed 2D sin-cos positional embeddings.

    DONE:
      - Implement 2D sin/cos embedding generation
      - Return shape:
            [1 + grid_size*grid_size, embed_dim] if cls_token
            [grid_size*grid_size, embed_dim] otherwise
    """
    half_dim = embed_dim//2
    
    x_coord = np.arange(grid_size, dtype=np.float32) 
    y_coord = np.arange(grid_size, dtype=np.float32) 

    grid_x, grid_y = np.meshgrid(x_coord, y_coord)

    pos_x = grid_x.flatten() #[0, 1, 2, 0, 1, 2...]
    pos_y = grid_y.flatten() #[0, 0, 0, 1, 1, 1...]


    #1/4 for xdim sin, 1/4 for xdim cos... etc
    broadcast = np.arange(half_dim // 2, dtype=np.float32) 
    div_term = 1. / (10000 ** (broadcast / (half_dim // 2)))
    
    out_x = pos_x[:, np.newaxis] * div_term
    out_y = pos_y[:, np.newaxis] * div_term
    
    emb_x = np.concatenate([np.sin(out_x) , np.cos(out_x)], axis=1)
    emb_y = np.concatenate([np.sin(out_y), np.cos(out_y)], axis=1)

    pos_embed = np.concatenate([emb_y, emb_x], axis=1)

    if cls_token:
        cls = np.zeros((1, embed_dim))
        pos_embed = np.concatenate([cls, pos_embed], axis = 0)
        
    return pos_embed

@torch.no_grad()
def pre_extract_mae_features(mae_model, loader):
    device = next(mae_model.parameters()).device
    mae_model.eval()
    
    all_features = []
    all_labels = []
    
    print(f"Pre-extracting features for {len(loader.dataset)} images...")
    for imgs, labels in tqdm(loader):
        imgs = imgs.to(device)
        # Pass through the frozen MAE encoder once
        feat = get_mae_features(mae_model, imgs) 
        all_features.append(feat.cpu())
        all_labels.append(labels.cpu())
        
    return torch.cat(all_features), torch.cat(all_labels)


class PatchEmbed(nn.Module):
    """
    Standard ViT-style patch embedding using a Conv2d with
    kernel_size = stride = patch_size.
    """

    def __init__(self, img_size=224, patch_size=16, in_chans=3, embed_dim=768):
        super().__init__()
        assert img_size % patch_size == 0
        self.img_size = img_size
        self.patch_size = patch_size
        self.grid_size = img_size // patch_size
        self.num_patches = self.grid_size * self.grid_size

        self.proj = nn.Conv2d(
            in_chans, embed_dim,
            kernel_size=patch_size,
            stride=patch_size
        )

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        """
        x: [B, C, H, W]
        returns: [B, L, D]
        """
        x = self.proj(x)                  # [B, D, Gh, Gw]
        x = x.flatten(2).transpose(1, 2) # [B, L, D]
        return x


class MLP(nn.Module):
    def __init__(self, dim: int, hidden_dim: int):
        super().__init__()
        self.fc1 = nn.Linear(dim, hidden_dim)
        self.act = nn.GELU()
        self.fc2 = nn.Linear(hidden_dim, dim)

    def forward(self, x):
        return self.fc2(self.act(self.fc1(x)))


class TransformerBlock(nn.Module):
    """
    Minimal ViT block scaffold.

    TODO:
      - Optionally swap with timm VisionTransformer block
      - Add dropout / droppath if desired
    """

    def __init__(self, dim: int, num_heads: int, mlp_ratio: float = 4.0):
        super().__init__()
        self.norm1 = nn.LayerNorm(dim)
        self.attn = nn.MultiheadAttention(
            embed_dim=dim,
            num_heads=num_heads,
            batch_first=True,
        )
        self.norm2 = nn.LayerNorm(dim)
        self.mlp = MLP(dim, int(dim * mlp_ratio))

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        x_norm = self.norm1(x)
        attn_out, _ = self.attn(x_norm, x_norm, x_norm, need_weights=False)
        x = x + attn_out
        x = x + self.mlp(self.norm2(x))
        return x


# ------------------------------------------------------------
# MAE
# ------------------------------------------------------------

class MaskedAutoencoderViT(nn.Module):
    """
    MAE scaffold matching the paper's core design:
      1. patchify image
      2. randomly mask patches
      3. encoder sees only visible patches
      4. decoder receives encoded visible tokens + mask tokens
      5. reconstruct pixels
      6. loss only on masked patches
    """

    def __init__(self, cfg: MAEConfig):
        super().__init__()
        self.cfg = cfg
        
        # ----- patch embedding -----
        self.patch_embed = PatchEmbed(
            img_size=cfg.img_size,
            patch_size=cfg.patch_size,
            in_chans=cfg.in_chans,
            embed_dim=cfg.enc_embed_dim,
        )
        num_patches = self.patch_embed.num_patches

        # ----- encoder -----
        self.cls_token = nn.Parameter(torch.zeros(1, 1, cfg.enc_embed_dim))
        self.pos_embed_enc = nn.Parameter(
            torch.zeros(1, num_patches + 1, cfg.enc_embed_dim),
            requires_grad=False,  # fixed sin-cos in original MAE
        )

        self.encoder_blocks = nn.ModuleList([
            TransformerBlock(cfg.enc_embed_dim, cfg.enc_num_heads, cfg.mlp_ratio)
            for _ in range(cfg.enc_depth)
        ])
        self.enc_norm = nn.LayerNorm(cfg.enc_embed_dim)

        # ----- decoder -----
        self.decoder_embed = nn.Linear(cfg.enc_embed_dim, cfg.dec_embed_dim)
        self.mask_token = nn.Parameter(torch.zeros(1, 1, cfg.dec_embed_dim))

        self.pos_embed_dec = nn.Parameter(
            torch.zeros(1, num_patches + 1, cfg.dec_embed_dim),
            requires_grad=False,
        )

        self.decoder_blocks = nn.ModuleList([
            TransformerBlock(cfg.dec_embed_dim, cfg.dec_num_heads, cfg.mlp_ratio)
            for _ in range(cfg.dec_depth)
        ])
        self.dec_norm = nn.LayerNorm(cfg.dec_embed_dim)

        patch_dim = cfg.patch_size * cfg.patch_size * cfg.in_chans
        self.decoder_pred = nn.Linear(cfg.dec_embed_dim, patch_dim)

        self.initialize_weights()

    # --------------------------------------------------------
    # initialization
    # --------------------------------------------------------

    def initialize_weights(self):
        """
        TODO:
          - Fill fixed sin-cos positional embeddings
          - Init cls token, mask token, and linear weights
        """
        grid = self.patch_embed.grid_size

        # Fixed sin-cos positional embeddings.
        pos_enc = get_2d_sincos_pos_embed(self.cfg.enc_embed_dim, grid, cls_token=True)
        self.pos_embed_enc.data.copy_(torch.from_numpy(pos_enc).float().unsqueeze(0))

        pos_dec = get_2d_sincos_pos_embed(self.cfg.dec_embed_dim, grid, cls_token=True)
        self.pos_embed_dec.data.copy_(torch.from_numpy(pos_dec).float().unsqueeze(0))

        nn.init.normal_(self.cls_token, std=0.02)
        nn.init.normal_(self.mask_token, std=0.02)

        self.apply(self._init_weights)

    def _init_weights(self, m):
        if isinstance(m, nn.Linear):
            nn.init.xavier_uniform_(m.weight)
            if m.bias is not None:
                nn.init.zeros_(m.bias)
                
        elif isinstance(m, nn.Conv2d):
            nn.init.xavier_uniform_(m.weight.view(m.weight.shape[0], -1))
            if m.bias is not None:
                nn.init.zeros_(m.bias)
                
        elif isinstance(m, nn.LayerNorm):
            nn.init.ones_(m.weight)
            nn.init.zeros_(m.bias)

    # --------------------------------------------------------
    # patch utilities
    # --------------------------------------------------------

    def patchify(self, imgs: torch.Tensor) -> torch.Tensor:
        """
        imgs: [B, C, H, W]
        returns patches: [B, L, patch_size^2 * C]
        """
        p = self.cfg.patch_size
        B, C, H, W = imgs.shape
        assert H == W and H % p == 0

        h = w = H // p
        x = imgs.reshape(B, C, h, p, w, p)
        x = torch.einsum("nchpwq->nhwpqc", x)
        x = x.reshape(B, h * w, p * p * C)
        return x

    def unpatchify(self, x: torch.Tensor) -> torch.Tensor:
        """
        x: [B, L, patch_size^2 * C]
        returns imgs: [B, C, H, W]
        """
        p = self.cfg.patch_size
        B, L, D = x.shape
        h = w = int(L ** 0.5)
        assert h * w == L
        C = self.cfg.in_chans
        assert D == p * p * C

        x = x.reshape(B, h, w, p, p, C)
        x = torch.einsum("nhwpqc->nchpwq", x)
        imgs = x.reshape(B, C, h * p, w * p)
        return imgs

    # --------------------------------------------------------
    # masking
    # --------------------------------------------------------

    def random_masking(self, x: torch.Tensor, mask_ratio: float):
        """
        Per-sample random masking by per-sample shuffling.

        x: [B, L, D]
        returns:
          x_masked: [B, L_keep, D]
          mask:     [B, L] where 1 = masked, 0 = kept
          ids_restore: [B, L] indices to undo shuffle
          ids_keep: [B, L_keep]
        """
        B, L, D = x.shape
        len_keep = int(L * (1 - mask_ratio))

        noise = torch.rand(B, L, device=x.device)
        ids_shuffle = torch.argsort(noise, dim=1)
        ids_restore = torch.argsort(ids_shuffle, dim=1)

        ids_keep = ids_shuffle[:, :len_keep]
        x_masked = torch.gather(
            x, dim=1,
            index=ids_keep.unsqueeze(-1).expand(-1, -1, D)
        )

        mask = torch.ones(B, L, device=x.device)
        mask[:, :len_keep] = 0
        mask = torch.gather(mask, dim=1, index=ids_restore)

        return x_masked, mask, ids_restore, ids_keep

    # --------------------------------------------------------
    # encoder
    # --------------------------------------------------------

    def forward_encoder(self, imgs: torch.Tensor, mask_ratio: float):
        """
        Encoder sees only visible patches, not mask tokens.
        """
        x = self.patch_embed(imgs)                    # [B, L, D]
        x = x + self.pos_embed_enc[:, 1:, :]         # patch positions only

        x, mask, ids_restore, ids_keep = self.random_masking(x, mask_ratio)

        cls_token = self.cls_token + self.pos_embed_enc[:, :1, :]
        cls_tokens = cls_token.expand(x.shape[0], -1, -1)
        x = torch.cat([cls_tokens, x], dim=1)

        for blk in self.encoder_blocks:
            x = blk(x)
        x = self.enc_norm(x)

        return x, mask, ids_restore

    # --------------------------------------------------------
    # decoder
    # --------------------------------------------------------

    def forward_decoder(self, latent: torch.Tensor, ids_restore: torch.Tensor):
        """
        Reinsert mask tokens after the encoder, then decode all patches.
        """
        x = self.decoder_embed(latent)   # [B, 1 + L_keep, D_dec]

        # split cls / patch tokens
        cls_token = x[:, :1, :]
        x_vis = x[:, 1:, :]              # visible patch tokens only

        B, L_keep, D = x_vis.shape
        L_full = ids_restore.shape[1]
        num_mask = L_full - L_keep

        mask_tokens = self.mask_token.expand(B, num_mask, D)

        x_full = torch.cat([x_vis, mask_tokens], dim=1)  # shuffled order
        x_full = torch.gather(
            x_full, dim=1,
            index=ids_restore.unsqueeze(-1).expand(-1, -1, D)
        )

        x = torch.cat([cls_token, x_full], dim=1)
        x = x + self.pos_embed_dec

        for blk in self.decoder_blocks:
            x = blk(x)
        x = self.dec_norm(x)

        pred = self.decoder_pred(x[:, 1:, :])  # remove cls token
        return pred  # [B, L, patch_dim]

    # --------------------------------------------------------
    # loss
    # --------------------------------------------------------

    def forward_loss(self, imgs: torch.Tensor, pred: torch.Tensor, mask: torch.Tensor):
        """
        Compute reconstruction loss only on masked patches.

        pred: [B, L, patch_dim]
        mask: [B, L], 1 = masked, 0 = visible
        """
        target = self.patchify(imgs)

        if self.cfg.norm_pix_loss:
            mean = target.mean(dim=-1, keepdim=True)
            var = target.var(dim=-1, keepdim=True)
            target = (target - mean) / (var + 1.0e-6).sqrt()

        loss = (pred - target) ** 2
        loss = loss.mean(dim=-1)  # per patch

        # only masked patches contribute
        loss = (loss * mask).sum() / mask.sum()
        return loss

    # --------------------------------------------------------
    # main forward
    # --------------------------------------------------------

    def forward(self, imgs: torch.Tensor, mask_ratio: float = None):
        if mask_ratio is None:
            mask_ratio = self.cfg.mask_ratio

        latent, mask, ids_restore = self.forward_encoder(imgs, mask_ratio)
        pred = self.forward_decoder(latent, ids_restore)
        loss = self.forward_loss(imgs, pred, mask)

        return {
            "loss": loss,
            "pred": pred,
            "mask": mask,
        }
    #visualizer
    @torch.no_grad()
    def visualize(self, imgs: torch.Tensor):
        results = self.forward(imgs)
        pred, mask = results["pred"], results["mask"] # loss removed
        target = self.patchify(imgs)
        

        if self.cfg.norm_pix_loss:
            mean = target.mean(dim=-1, keepdim=True)
            var = target.var(dim=-1, keepdim=True)
            pred = pred * (var + 1.0e-6).sqrt() + mean
            
        # Where mask == 0, use original pixels. Where mask == 1, use predicted pixels.
        # res_patches shape: [B, L, patch_dim]
        mask_expanded = mask.unsqueeze(-1)
        res_patches = target * (1 - mask_expanded) + pred * mask_expanded
        reconstructed_img = self.unpatchify(res_patches)
        
        # We set masked areas to 0 (black) or 1 (white)
        im_masked = target * (1 - mask_expanded)
        im_masked = self.unpatchify(im_masked)
        
        return reconstructed_img, im_masked

# %% [markdown]
# # Train MAE

# %%
def train_mae_model(model: nn.Module, 
                    train_loader: DataLoader, 
                    epochs: int, 
                    lr: float,
                    checkpoint_path: str = "mae_checkpoint.pth",
                    start_epoch: int = 0): # Added this parameter
    
    model.to(device)
    opt = torch.optim.AdamW(model.parameters(), lr=lr, weight_decay=0.05)
    
    # If we are resuming, we need to load the optimizer state too
    if start_epoch > 0:
        checkpoint = torch.load(checkpoint_path, map_location=device)
        opt.load_state_dict(checkpoint['optimizer_state_dict'])
        print(f"Optimizer state restored from epoch {start_epoch}")

    results = {"train_loss": []}
    best_loss = float('inf')

    # Change range to start from start_epoch + 1
    for ep in range(start_epoch + 1, epochs + 1):
        running = 0.0
        n_batches = 0
        pbar = tqdm(train_loader, desc=f"Epoch {ep}/{epochs}", leave=False)
        
        model.train()
        for sample in pbar:
            imgs, _ = sample 
            imgs = imgs.to(device)
            
            output = model(imgs)
            loss = output["loss"]
            
            opt.zero_grad()
            loss.backward()
            opt.step()

            running += float(loss.item())
            n_batches += 1
            pbar.set_postfix(loss=running / n_batches)
        
        train_loss = running / max(1, n_batches)
        torch.cuda.empty_cache()
        results["train_loss"].append(train_loss)
        
        # Save logic remains the same
        if train_loss < best_loss:
            best_loss = train_loss
            torch.save({
                'epoch': ep,
                'model_state_dict': model.state_dict(),
                'optimizer_state_dict': opt.state_dict(),
                'loss': train_loss,
            }, checkpoint_path)
        
        # Visualization logic remains the same...
        if ep % 10 == 0:
            model.eval()
            with torch.no_grad():
                recon, masked = model.visualize(imgs[:1])
                plt.figure(figsize=(12, 4))
                plt.subplot(1, 3, 1); plt.imshow(denormalize(imgs[0])); plt.title("Original")
                plt.subplot(1, 3, 2); plt.imshow(denormalize(masked[0])); plt.title("Masked")
                plt.subplot(1, 3, 3); plt.imshow(denormalize(recon[0])); plt.title("MAE Reconstruction")
                plt.show()
                plt.close()
            model.train()

    return results

# %%
import torch
# 1. Make sure your data directory is still correct
# train_dir = "./path/to/your/data" 

# 2. Re-create the data loader
mae_train_loader = get_mae_dataloader(train_dir, batch_size=64)

print(f"Data loader ready with {len(mae_train_loader)} batches.")
# 1. Define paths and device
checkpoint_path = "mae_vit_768_e16.pth"
device = "cuda" if torch.cuda.is_available() else "cpu"

# 2. RE-INITIALIZE the model skeleton
# (This is what was missing in your current cell)
cfg = MAEConfig() 
mae_model = MaskedAutoencoderViT(cfg).to(device)

# 3. Load the checkpoint
if os.path.exists(checkpoint_path):
    print(f"Loading checkpoint from {checkpoint_path}...")
    checkpoint = torch.load(checkpoint_path, map_location=device)
    
    # Load the weights into the skeleton
    mae_model.load_state_dict(checkpoint['model_state_dict'])
    last_ep = checkpoint['epoch']
    print(f"Success! Resuming from epoch {last_ep}")
    
    # 4. Call the trainer
    results = train_mae_model(
        model=mae_model,
        train_loader=mae_train_loader, # Make sure this is defined!
        epochs=100,      
        lr=1.5e-4,
        checkpoint_path=checkpoint_path,
        start_epoch=last_ep 
    )
else:
    results = train_mae_model(
        model=mae_model,
        train_loader=mae_train_loader,
        epochs=100,      
        lr=1.5e-4,
        checkpoint_path=checkpoint_path,
        start_epoch=0 
    )
# Out:
# Data loader ready with 97 batches.
# Epoch 6/100:  79%|██████████████▎   | 77/97 [00:26<00:06,  2.95it/s, loss=0.601]

# %% [markdown]
# ## Evaluate with linear probe

# %%
probe_train_set = make_gpu_dataset(train_dir, simclr_test_transform, False)
probe_val_set = make_gpu_dataset(val_dir, simclr_test_transform, False)
probe_test_set = make_gpu_dataset(test_dir, simclr_test_transform, False)

probe_train_loader = DataLoader(probe_train_set, 
                          batch_size=128, 
                          shuffle=True, 
                          num_workers=4, 
                          drop_last=True)

probe_val_loader = DataLoader(probe_val_set, 
                          batch_size=128, 
                          shuffle=True, 
                          num_workers=4, 
                          drop_last=True)

probe_test_loader = DataLoader(probe_test_set, 
                          batch_size=128, 
                          shuffle=True, 
                          num_workers=4, 
                          drop_last=True)

def train_classifier(encoder: nn.Module,
                     classifier: nn.Module, 
                     train_loader: DataLoader,
                     val_loader: DataLoader,
                     epochs: int, 
                     lr: float):
    
    results = {"train_loss": [], "val_loss": []}
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(classifier.parameters(), lr=lr)
    
    encoder.eval()
    for epoch in range(epochs):
        train_loss = 0
        train_running = 0
        pbar = tqdm(train_loader, desc=f"epoch {epoch}/{epochs}", leave=False)
        n_batches = 0
        for sample in pbar:
            view, label = sample
            with torch.no_grad():
                features = encoder.representation(view)

            outputs = classifier(features)
            loss = criterion(outputs, label)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            train_running += float(loss.item())
            n_batches += 1
            pbar.set_postfix(loss=train_running / n_batches)
        
        train_loss = train_running / max(1, n_batches)
        
        val_loss = 0
        val_running = 0
        with torch.no_grad():
            n_batches = 0
            for sample in val_loader:
                features = encoder.representation(view)
                outputs = classifier(features)
                loss = criterion(outputs, label)
                val_running += float(loss.item())
                n_batches += 1

        val_loss = val_running / max(1, n_batches)
        results["train_loss"].append(train_loss)
        results["val_loss"].append(val_loss)
        if epoch % 10 == 0:
            print(f"epoch {epoch}: train_loss={train_loss:.4f}, val_loss={val_loss:.4f}")
    results['classifier'] = classifier
    return results

# %%
linear_probe = nn.Linear(512, 102).to(device)
epochs = 250
lr = 1e-3
classifier_results = train_classifier(simCLR, linear_probe, probe_train_loader, probe_val_loader, epochs, lr)

# %%
from matplotlib import pyplot as plt
plt.plot(classifier_results['train_loss'])
plt.plot(classifier_results['val_loss'])

# %%
def evaluate(model, classifier, loader):
    model.eval()
    classifier.eval()
    
    correct = 0
    total = 0
    with torch.no_grad():
        for images, labels in loader:

            images = images.to(device)
            labels = labels.to(device)

            features = model.representation(images)
            outputs = classifier(features)

            preds = outputs.argmax(dim=1)

            correct += (preds == labels).sum().item()
            total += labels.size(0)

    return correct / total

# %%
train_acc = evaluate(simCLR, linear_probe, probe_train_loader)
val_acc = evaluate(simCLR, linear_probe, probe_val_loader)
test_acc = evaluate(simCLR, linear_probe, probe_test_loader)

print("Train:", train_acc)
print("Val:", val_acc)
print("Test:", test_acc)

# %%
class MLPClassifier(nn.Module):
    def __init__(self, input_dim, hidden_dim, num_classes):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(input_dim, hidden_dim),
            nn.BatchNorm1d(hidden_dim),
            nn.GELU(),
            nn.Dropout(0.2), # Optional: prevents overfitting on the small head
            nn.Linear(hidden_dim, num_classes)
        )

    def forward(self, x):
        return self.net(x)

class MLP(nn.Module):
    def __init__(self, dim: int, hidden_dim: int, out_dim: int):
        super().__init__()
        self.fc1 = nn.Linear(dim, hidden_dim)
        self.act = nn.GELU()
        self.fc2 = nn.Linear(hidden_dim, out_dim)

    def forward(self, x):
        return self.fc2(self.act(self.fc1(x)))
def train_fast_probe(classifier, train_loader, val_loader, epochs=250, lr=1e-3):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    classifier.to(device)
    
    optimizer = torch.optim.AdamW(classifier.parameters(), lr=lr, weight_decay=0.01)
    criterion = nn.CrossEntropyLoss()
    history = {"train_loss": [], "val_acc": []}

    for ep in range(epochs):
        classifier.train()
        running_loss = 0
        
        for features, labels in train_loader:
            features, labels = features.to(device), labels.to(device)

            logits = classifier(features)
            loss = criterion(logits, labels)
            
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            running_loss += loss.item()

        # Validation
        classifier.eval()
        correct, total = 0, 0
        with torch.no_grad():
            for features, labels in val_loader:
                features, labels = features.to(device), labels.to(device)
                logits = classifier(features)
                preds = torch.argmax(logits, dim=1)
                correct += (preds == labels).sum().item()
                total += labels.size(0)
        
        acc = 100 * correct / total
        history["train_loss"].append(running_loss / len(train_loader))
        history["val_acc"].append(acc)
        
        if (ep + 1) % 10 == 0 or ep == 0:
            print(f"Epoch {ep+1}/{epochs} | Loss: {history['train_loss'][-1]:.4f} | Acc: {acc:.2f}%")

    return history

# 1. Define a "Clean" transform for the Probe (no random flipping/cropping)
probe_test_transform = T.Compose([
    T.Resize(256),
    T.CenterCrop(224),
    T.ToTensor(),
    T.Normalize(mean, std)
])

# 2. Update your loader function to be flexible
def get_probe_dataloader(data_dir, transform, batch_size=128, shuffle=True):
    dataset = ImageFolder(root=data_dir, transform=transform)
    loader = DataLoader(
        dataset,
        batch_size=batch_size,
        shuffle=shuffle,
        num_workers=4,
        pin_memory=True
    )
    return loader

# 3. Create the missing loaders
probe_train_loader = get_probe_dataloader(train_dir, probe_test_transform, shuffle=True)
probe_val_loader = get_probe_dataloader(val_dir, probe_test_transform, shuffle=False)

# %%
class MLP_3Layer(nn.Module):
    def __init__(self, dim, h1, h2, out):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(dim, h1),
            nn.GELU(),
            nn.Linear(h1, h2),
            nn.GELU(),
            nn.Linear(h2, out)
        )
    def forward(self, x): return self.net(x)

# 1. Pre-extract features to avoid running the MAE 1000 times
# Run this ONCE before starting experiments
print("Pre-extracting features (doing the heavy lifting once)...")
train_feat, train_labels = pre_extract_mae_features(mae_model, probe_train_loader)
val_feat, val_labels = pre_extract_mae_features(mae_model, probe_val_loader)

# 2. Create the fast loaders
fast_train_loader = DataLoader(TensorDataset(train_feat, train_labels), batch_size=256, shuffle=True)
fast_val_loader = DataLoader(TensorDataset(val_feat, val_labels), batch_size=256)

# ------------------------------------------------------------
# Experiments (Now using train_fast_probe)
# ------------------------------------------------------------
num_classes = 102
embed_dim = 768

# --- Experiment 1: Linear Probe ---
print("\nStarting Linear Probe...")
linear_head = nn.Linear(embed_dim, num_classes)
# Note: We use the fast loader and the fast training function here
linear_history = train_fast_probe(linear_head, fast_train_loader, fast_val_loader, epochs=1000)

# --- Experiment 2: MLP Probe (with BatchNorm/Dropout) ---
print("\nStarting MLP Probe...")
mlp_head = MLPClassifier(embed_dim, 512, num_classes)
mlp_history = train_fast_probe(mlp_head, fast_train_loader, fast_val_loader, epochs=1000)

# --- Experiment 3: Simple MLP Probe (3-layer) ---
print("\nStarting MLP1 Probe...")
# Check your MLP definition: if it takes 4 args, use (dim, hidden1, hidden2, out)
# If your MLP only takes 3, you may need to adjust the class definition
mlp1_head = MLP_3Layer(embed_dim, 512, 256, num_classes) 
mlp1_history = train_fast_probe(mlp1_head, fast_train_loader, fast_val_loader, epochs=1000)

# --- Experiment 4: Simple MLP Probe (2-layer) ---
print("\nStarting MLP2 Probe...")
mlp2_head = MLP(embed_dim, 512, num_classes)
mlp2_history = train_fast_probe(mlp2_head, fast_train_loader, fast_val_loader, epochs=1000)

# --- Plot Comparison ---
# (Your plotting code remains the same!)
# --- Plot Comparison ---

plt.figure(figsize=(10, 5))

plt.plot(linear_history["val_acc"], label="Linear Probe")

plt.plot(mlp_history["val_acc"], label="MLP Probe (Hidden: 512)")

plt.plot(mlp1_history["val_acc"], label="Simple MLP Probe (Hidden: 512, 256)")

plt.plot(mlp2_history["val_acc"], label="Simple MLP Probe (Hidden: 512)")

plt.title("Probing MAE Features: Linear vs MLP")

plt.xlabel("Epoch")

plt.ylabel("Validation Accuracy %")

plt.legend()

plt.grid(True)

plt.show()
# Out:
# Pre-extracting features (doing the heavy lifting once)...
# Pre-extracting features for 6149 images...
# 100%|███████████████████████████████████████████| 49/49 [00:22<00:00,  2.15it/s]
# Pre-extracting features for 1020 images...
# 100%|█████████████████████████████████████████████| 8/8 [00:04<00:00,  1.89it/s]
# Starting Linear Probe...
# Epoch 1/1000 | Loss: 4.2367 | Acc: 4.51%
# Epoch 10/1000 | Loss: 2.5674 | Acc: 24.80%
# Epoch 20/1000 | Loss: 2.0973 | Acc: 37.45%
# Epoch 30/1000 | Loss: 1.8130 | Acc: 45.20%
# Epoch 40/1000 | Loss: 1.6442 | Acc: 48.73%
# Epoch 50/1000 | Loss: 1.5177 | Acc: 49.51%
# Epoch 60/1000 | Loss: 1.4431 | Acc: 52.94%
# Epoch 70/1000 | Loss: 1.4075 | Acc: 54.71%
# Epoch 80/1000 | Loss: 1.2788 | Acc: 55.69%
# Epoch 90/1000 | Loss: 1.2780 | Acc: 55.98%
# Epoch 100/1000 | Loss: 1.1703 | Acc: 58.14%
# Epoch 110/1000 | Loss: 1.0972 | Acc: 58.53%
# Epoch 120/1000 | Loss: 1.0622 | Acc: 59.71%
# Epoch 130/1000 | Loss: 1.0613 | Acc: 58.53%
# Epoch 140/1000 | Loss: 0.9906 | Acc: 60.88%
# Epoch 150/1000 | Loss: 0.9591 | Acc: 61.57%
# Epoch 160/1000 | Loss: 0.9623 | Acc: 61.37%
# Epoch 170/1000 | Loss: 0.9074 | Acc: 62.06%
# Epoch 180/1000 | Loss: 0.8748 | Acc: 62.65%
# Epoch 190/1000 | Loss: 0.8760 | Acc: 62.94%
# Epoch 200/1000 | Loss: 0.8384 | Acc: 63.04%
# Epoch 210/1000 | Loss: 0.8590 | Acc: 64.51%
# Epoch 220/1000 | Loss: 0.8135 | Acc: 64.02%
# Epoch 230/1000 | Loss: 0.7887 | Acc: 64.22%
# Epoch 240/1000 | Loss: 0.7784 | Acc: 64.90%
# Epoch 250/1000 | Loss: 0.7311 | Acc: 64.41%
# Epoch 260/1000 | Loss: 0.7329 | Acc: 64.90%
# Epoch 270/1000 | Loss: 0.7115 | Acc: 64.90%
# Epoch 280/1000 | Loss: 0.6862 | Acc: 64.31%
# Epoch 290/1000 | Loss: 0.6958 | Acc: 64.71%
# Epoch 300/1000 | Loss: 0.6697 | Acc: 65.39%
# Epoch 310/1000 | Loss: 0.6446 | Acc: 65.98%
# Epoch 320/1000 | Loss: 0.6378 | Acc: 65.00%
# Epoch 330/1000 | Loss: 0.6635 | Acc: 65.39%
# Epoch 340/1000 | Loss: 0.6464 | Acc: 66.08%
# Epoch 350/1000 | Loss: 0.6474 | Acc: 65.98%
# Epoch 360/1000 | Loss: 0.6371 | Acc: 66.37%
# Epoch 370/1000 | Loss: 0.6254 | Acc: 66.08%
# Epoch 380/1000 | Loss: 0.5645 | Acc: 66.76%
# Epoch 390/1000 | Loss: 0.6044 | Acc: 66.76%
# Epoch 400/1000 | Loss: 0.5496 | Acc: 66.37%
# Epoch 410/1000 | Loss: 0.5494 | Acc: 66.47%
# Epoch 420/1000 | Loss: 0.5404 | Acc: 66.37%
# Epoch 430/1000 | Loss: 0.5452 | Acc: 66.96%
# Epoch 440/1000 | Loss: 0.5176 | Acc: 67.35%
# Epoch 450/1000 | Loss: 0.5147 | Acc: 67.06%
# Epoch 460/1000 | Loss: 0.5001 | Acc: 67.35%
# Epoch 470/1000 | Loss: 0.5093 | Acc: 67.55%
# Epoch 480/1000 | Loss: 0.5185 | Acc: 66.67%
# Epoch 490/1000 | Loss: 0.4639 | Acc: 67.35%
# Epoch 500/1000 | Loss: 0.5065 | Acc: 66.96%
# Epoch 510/1000 | Loss: 0.4681 | Acc: 67.25%
# Epoch 520/1000 | Loss: 0.4797 | Acc: 67.84%
# Epoch 530/1000 | Loss: 0.4565 | Acc: 67.45%
# Epoch 540/1000 | Loss: 0.4557 | Acc: 67.06%
# Epoch 550/1000 | Loss: 0.4300 | Acc: 67.75%
# Epoch 560/1000 | Loss: 0.4403 | Acc: 68.04%
# Epoch 570/1000 | Loss: 0.4514 | Acc: 67.45%
# Epoch 580/1000 | Loss: 0.4318 | Acc: 67.65%
# Epoch 590/1000 | Loss: 0.4131 | Acc: 67.55%
# Epoch 600/1000 | Loss: 0.4232 | Acc: 67.75%
# Epoch 610/1000 | Loss: 0.4104 | Acc: 68.73%
# Epoch 620/1000 | Loss: 0.3891 | Acc: 67.65%
# Epoch 630/1000 | Loss: 0.3958 | Acc: 68.24%
# Epoch 640/1000 | Loss: 0.3855 | Acc: 68.43%
# Epoch 650/1000 | Loss: 0.3920 | Acc: 68.24%
# Epoch 660/1000 | Loss: 0.4164 | Acc: 68.43%
# Epoch 670/1000 | Loss: 0.3782 | Acc: 67.84%
# Epoch 680/1000 | Loss: 0.3977 | Acc: 68.73%
# Epoch 690/1000 | Loss: 0.4080 | Acc: 68.33%
# Epoch 700/1000 | Loss: 0.3774 | Acc: 68.53%
# Epoch 710/1000 | Loss: 0.3605 | Acc: 68.43%
# Epoch 720/1000 | Loss: 0.3633 | Acc: 69.02%
# Epoch 730/1000 | Loss: 0.3641 | Acc: 68.82%
# Epoch 740/1000 | Loss: 0.3441 | Acc: 68.33%
# Epoch 750/1000 | Loss: 0.3460 | Acc: 68.92%
# Epoch 760/1000 | Loss: 0.3307 | Acc: 68.82%
# Epoch 770/1000 | Loss: 0.3427 | Acc: 68.63%
# Epoch 780/1000 | Loss: 0.3361 | Acc: 68.73%
# Epoch 790/1000 | Loss: 0.3316 | Acc: 68.82%
# Epoch 800/1000 | Loss: 0.3461 | Acc: 68.53%
# Epoch 810/1000 | Loss: 0.3152 | Acc: 69.12%
# Epoch 820/1000 | Loss: 0.3147 | Acc: 69.02%
# Epoch 830/1000 | Loss: 0.3093 | Acc: 68.92%
# Epoch 840/1000 | Loss: 0.3125 | Acc: 68.92%
# Epoch 850/1000 | Loss: 0.2924 | Acc: 68.82%
# Epoch 860/1000 | Loss: 0.3106 | Acc: 69.12%
# Epoch 870/1000 | Loss: 0.2954 | Acc: 69.31%
# Epoch 880/1000 | Loss: 0.2960 | Acc: 69.02%
# Epoch 890/1000 | Loss: 0.2863 | Acc: 69.12%
# Epoch 900/1000 | Loss: 0.2947 | Acc: 68.53%
# Epoch 910/1000 | Loss: 0.2814 | Acc: 68.92%
# Epoch 920/1000 | Loss: 0.2945 | Acc: 69.41%
# Epoch 930/1000 | Loss: 0.2854 | Acc: 69.80%
# Epoch 940/1000 | Loss: 0.2718 | Acc: 68.82%
# Epoch 950/1000 | Loss: 0.2645 | Acc: 69.51%
# Epoch 960/1000 | Loss: 0.2647 | Acc: 69.22%
# Epoch 970/1000 | Loss: 0.2757 | Acc: 69.31%
# Epoch 980/1000 | Loss: 0.2568 | Acc: 69.61%
# Epoch 990/1000 | Loss: 0.2659 | Acc: 68.92%
# Epoch 1000/1000 | Loss: 0.2698 | Acc: 68.43%
#
# Starting MLP Probe...
# Epoch 1/1000 | Loss: 3.3238 | Acc: 10.78%
# Epoch 10/1000 | Loss: 0.9520 | Acc: 62.16%
# Epoch 20/1000 | Loss: 0.7321 | Acc: 64.71%
# Epoch 30/1000 | Loss: 0.6151 | Acc: 67.16%
# Epoch 40/1000 | Loss: 0.6181 | Acc: 67.45%
# Epoch 50/1000 | Loss: 0.5285 | Acc: 67.75%
# Epoch 60/1000 | Loss: 0.4627 | Acc: 69.61%
# Epoch 70/1000 | Loss: 0.5732 | Acc: 66.76%
# Epoch 80/1000 | Loss: 0.2587 | Acc: 70.20%
# Epoch 90/1000 | Loss: 0.3947 | Acc: 69.90%
# Epoch 100/1000 | Loss: 0.2868 | Acc: 69.61%
# Epoch 110/1000 | Loss: 0.2940 | Acc: 69.41%
# Epoch 120/1000 | Loss: 0.2922 | Acc: 69.90%
# Epoch 130/1000 | Loss: 0.3284 | Acc: 67.06%
# Epoch 140/1000 | Loss: 0.2650 | Acc: 68.63%
# Epoch 150/1000 | Loss: 0.2058 | Acc: 70.78%
# Epoch 160/1000 | Loss: 0.2561 | Acc: 70.98%
# Epoch 170/1000 | Loss: 0.1869 | Acc: 71.76%
# Epoch 180/1000 | Loss: 0.2590 | Acc: 70.29%
# Epoch 190/1000 | Loss: 0.2965 | Acc: 71.67%
# Epoch 200/1000 | Loss: 0.2236 | Acc: 70.49%
# Epoch 210/1000 | Loss: 0.1715 | Acc: 69.31%
# Epoch 220/1000 | Loss: 0.2234 | Acc: 70.39%
# Epoch 230/1000 | Loss: 0.2170 | Acc: 69.12%
# Epoch 240/1000 | Loss: 0.2790 | Acc: 70.88%
# Epoch 250/1000 | Loss: 0.2620 | Acc: 69.22%
# Epoch 260/1000 | Loss: 0.2295 | Acc: 69.80%
# Epoch 270/1000 | Loss: 0.2084 | Acc: 71.57%
# Epoch 280/1000 | Loss: 0.1680 | Acc: 71.47%
# Epoch 290/1000 | Loss: 0.1568 | Acc: 71.47%
# Epoch 300/1000 | Loss: 0.1398 | Acc: 70.98%
# Epoch 310/1000 | Loss: 0.0831 | Acc: 71.96%
# Epoch 320/1000 | Loss: 0.1662 | Acc: 70.29%
# Epoch 330/1000 | Loss: 0.2093 | Acc: 67.84%
# Epoch 340/1000 | Loss: 0.2706 | Acc: 70.98%
# Epoch 350/1000 | Loss: 0.1833 | Acc: 70.10%
# Epoch 360/1000 | Loss: 0.1985 | Acc: 70.29%
# Epoch 370/1000 | Loss: 0.1409 | Acc: 70.98%
# Epoch 380/1000 | Loss: 0.1523 | Acc: 69.90%
# Epoch 390/1000 | Loss: 0.1396 | Acc: 70.20%
# Epoch 400/1000 | Loss: 0.1767 | Acc: 71.37%
# Epoch 410/1000 | Loss: 0.1025 | Acc: 69.02%
# Epoch 420/1000 | Loss: 0.1540 | Acc: 69.90%
# Epoch 430/1000 | Loss: 0.2075 | Acc: 69.02%
# Epoch 440/1000 | Loss: 0.2290 | Acc: 70.49%
# Epoch 450/1000 | Loss: 0.2142 | Acc: 70.00%
# Epoch 460/1000 | Loss: 0.1292 | Acc: 70.59%
# Epoch 470/1000 | Loss: 0.1145 | Acc: 68.53%
# Epoch 480/1000 | Loss: 0.0673 | Acc: 70.10%
# Epoch 490/1000 | Loss: 0.3967 | Acc: 69.31%
# Epoch 500/1000 | Loss: 0.2242 | Acc: 69.41%
# Epoch 510/1000 | Loss: 0.1416 | Acc: 70.78%
# Epoch 520/1000 | Loss: 0.1108 | Acc: 70.39%
# Epoch 530/1000 | Loss: 0.1629 | Acc: 69.51%
# Epoch 540/1000 | Loss: 0.1348 | Acc: 70.10%
# Epoch 550/1000 | Loss: 0.1916 | Acc: 70.10%
# Epoch 560/1000 | Loss: 0.1662 | Acc: 68.33%
# Epoch 570/1000 | Loss: 0.1182 | Acc: 68.63%
# Epoch 580/1000 | Loss: 0.1322 | Acc: 69.90%
# Epoch 590/1000 | Loss: 0.1619 | Acc: 69.80%
# Epoch 600/1000 | Loss: 0.0655 | Acc: 69.41%
# Epoch 610/1000 | Loss: 0.1577 | Acc: 68.53%
# Epoch 620/1000 | Loss: 0.2136 | Acc: 68.14%
# Epoch 630/1000 | Loss: 0.0854 | Acc: 69.22%
# Epoch 640/1000 | Loss: 0.0959 | Acc: 69.61%
# Epoch 650/1000 | Loss: 0.1163 | Acc: 69.90%
# Epoch 660/1000 | Loss: 0.1144 | Acc: 69.02%
# Epoch 670/1000 | Loss: 0.1647 | Acc: 68.24%
# Epoch 680/1000 | Loss: 0.1140 | Acc: 70.39%
# Epoch 690/1000 | Loss: 0.1195 | Acc: 68.53%
# Epoch 700/1000 | Loss: 0.0610 | Acc: 69.31%
# Epoch 710/1000 | Loss: 0.1527 | Acc: 70.10%
# Epoch 720/1000 | Loss: 0.1701 | Acc: 69.31%
# Epoch 730/1000 | Loss: 0.1300 | Acc: 67.75%
# Epoch 740/1000 | Loss: 0.2376 | Acc: 70.39%
# Epoch 750/1000 | Loss: 0.1556 | Acc: 70.29%
# Epoch 760/1000 | Loss: 0.1597 | Acc: 69.80%
# Epoch 770/1000 | Loss: 0.1600 | Acc: 69.80%
# Epoch 780/1000 | Loss: 0.1159 | Acc: 69.31%
# Epoch 790/1000 | Loss: 0.2238 | Acc: 68.53%
# Epoch 800/1000 | Loss: 0.1659 | Acc: 68.82%
# Epoch 810/1000 | Loss: 0.1964 | Acc: 70.10%
# Epoch 820/1000 | Loss: 0.0902 | Acc: 70.69%
# Epoch 830/1000 | Loss: 0.1008 | Acc: 69.02%
# Epoch 840/1000 | Loss: 0.1090 | Acc: 69.90%
# Epoch 850/1000 | Loss: 0.1450 | Acc: 70.49%
# Epoch 860/1000 | Loss: 0.0642 | Acc: 69.71%
# Epoch 870/1000 | Loss: 0.0868 | Acc: 70.29%
# Epoch 880/1000 | Loss: 0.0746 | Acc: 70.39%
# Epoch 890/1000 | Loss: 0.0697 | Acc: 71.67%
# Epoch 900/1000 | Loss: 0.0536 | Acc: 70.78%
# Epoch 910/1000 | Loss: 0.1069 | Acc: 71.37%
# Epoch 920/1000 | Loss: 0.0936 | Acc: 70.29%
# Epoch 930/1000 | Loss: 0.1270 | Acc: 68.73%
# Epoch 940/1000 | Loss: 0.2143 | Acc: 70.29%
# Epoch 950/1000 | Loss: 0.0801 | Acc: 69.41%
# Epoch 960/1000 | Loss: 0.0939 | Acc: 68.43%
# Epoch 970/1000 | Loss: 0.1690 | Acc: 69.61%
# Epoch 980/1000 | Loss: 0.1140 | Acc: 69.02%
# Epoch 990/1000 | Loss: 0.1464 | Acc: 70.10%
# Epoch 1000/1000 | Loss: 0.0948 | Acc: 70.78%
#
# Starting MLP1 Probe...
# Epoch 1/1000 | Loss: 4.1616 | Acc: 5.00%
# Epoch 10/1000 | Loss: 1.6764 | Acc: 42.35%
# Epoch 20/1000 | Loss: 1.1747 | Acc: 53.04%
# Epoch 30/1000 | Loss: 0.9788 | Acc: 53.24%
# Epoch 40/1000 | Loss: 0.5954 | Acc: 59.31%
# Epoch 50/1000 | Loss: 0.6309 | Acc: 56.57%
# Epoch 60/1000 | Loss: 0.3524 | Acc: 60.00%
# Epoch 70/1000 | Loss: 0.2299 | Acc: 61.96%
# Epoch 80/1000 | Loss: 0.1332 | Acc: 61.67%
# Epoch 90/1000 | Loss: 0.0900 | Acc: 62.35%
# Epoch 100/1000 | Loss: 0.0584 | Acc: 60.98%
# Epoch 110/1000 | Loss: 0.0292 | Acc: 62.25%
# Epoch 120/1000 | Loss: 0.0238 | Acc: 61.27%
# Epoch 130/1000 | Loss: 0.0143 | Acc: 62.65%
# Epoch 140/1000 | Loss: 0.0127 | Acc: 62.06%
# Epoch 150/1000 | Loss: 0.0084 | Acc: 62.75%
# Epoch 160/1000 | Loss: 0.0077 | Acc: 62.16%
# Epoch 170/1000 | Loss: 0.0063 | Acc: 62.75%
# Epoch 180/1000 | Loss: 0.0045 | Acc: 63.24%
# Epoch 190/1000 | Loss: 0.0036 | Acc: 62.94%
# Epoch 200/1000 | Loss: 0.0043 | Acc: 63.04%
# Epoch 210/1000 | Loss: 0.0145 | Acc: 62.25%
# Epoch 220/1000 | Loss: 0.0031 | Acc: 63.92%
# Epoch 230/1000 | Loss: 0.0026 | Acc: 63.04%
# Epoch 240/1000 | Loss: 0.0028 | Acc: 62.75%
# Epoch 250/1000 | Loss: 0.0030 | Acc: 62.75%
# Epoch 260/1000 | Loss: 0.0023 | Acc: 62.06%
# Epoch 270/1000 | Loss: 0.0019 | Acc: 62.75%
# Epoch 280/1000 | Loss: 0.0018 | Acc: 62.84%
# Epoch 290/1000 | Loss: 0.0017 | Acc: 63.73%
# Epoch 300/1000 | Loss: 0.0014 | Acc: 63.04%
# Epoch 310/1000 | Loss: 0.0017 | Acc: 63.24%
# Epoch 320/1000 | Loss: 0.0015 | Acc: 62.84%
# Epoch 330/1000 | Loss: 0.0009 | Acc: 62.94%
# Epoch 340/1000 | Loss: 0.1223 | Acc: 28.24%
# Epoch 350/1000 | Loss: 0.0133 | Acc: 63.33%
# Epoch 360/1000 | Loss: 0.0026 | Acc: 63.63%
# Epoch 370/1000 | Loss: 0.0018 | Acc: 63.82%
# Epoch 380/1000 | Loss: 0.0017 | Acc: 63.53%
# Epoch 390/1000 | Loss: 0.0017 | Acc: 64.02%
# Epoch 400/1000 | Loss: 0.0018 | Acc: 64.22%
# Epoch 410/1000 | Loss: 0.0012 | Acc: 64.61%
# Epoch 420/1000 | Loss: 0.0012 | Acc: 64.41%
# Epoch 430/1000 | Loss: 0.0014 | Acc: 64.80%
# Epoch 440/1000 | Loss: 0.0029 | Acc: 63.33%
# Epoch 450/1000 | Loss: 0.0024 | Acc: 63.33%
# Epoch 460/1000 | Loss: 0.0011 | Acc: 63.92%
# Epoch 470/1000 | Loss: 0.0011 | Acc: 64.22%
# Epoch 480/1000 | Loss: 0.0008 | Acc: 63.82%
# Epoch 490/1000 | Loss: 0.0009 | Acc: 64.22%
# Epoch 500/1000 | Loss: 0.0008 | Acc: 63.92%
# Epoch 510/1000 | Loss: 0.0010 | Acc: 64.12%
# Epoch 520/1000 | Loss: 0.0009 | Acc: 63.82%
# Epoch 530/1000 | Loss: 0.0008 | Acc: 64.41%
# Epoch 540/1000 | Loss: 0.0006 | Acc: 64.12%
# Epoch 550/1000 | Loss: 0.0006 | Acc: 64.61%
# Epoch 560/1000 | Loss: 0.0007 | Acc: 64.22%
# Epoch 570/1000 | Loss: 0.0006 | Acc: 64.71%
# Epoch 580/1000 | Loss: 0.0006 | Acc: 64.61%
# Epoch 590/1000 | Loss: 0.0007 | Acc: 64.31%
# Epoch 600/1000 | Loss: 0.0007 | Acc: 64.41%
# Epoch 610/1000 | Loss: 0.0007 | Acc: 64.02%
# Epoch 620/1000 | Loss: 0.0005 | Acc: 64.41%
# Epoch 630/1000 | Loss: 0.0004 | Acc: 64.71%
# Epoch 640/1000 | Loss: 0.0006 | Acc: 64.71%
# Epoch 650/1000 | Loss: 0.0004 | Acc: 64.80%
# Epoch 660/1000 | Loss: 0.0005 | Acc: 64.12%
# Epoch 670/1000 | Loss: 0.0006 | Acc: 63.73%
# Epoch 680/1000 | Loss: 0.0005 | Acc: 63.63%
# Epoch 690/1000 | Loss: 0.0059 | Acc: 61.47%
# Epoch 700/1000 | Loss: 0.0023 | Acc: 62.25%
# Epoch 710/1000 | Loss: 0.0013 | Acc: 62.65%
# Epoch 720/1000 | Loss: 0.0012 | Acc: 62.75%
# Epoch 730/1000 | Loss: 0.0010 | Acc: 63.14%
# Epoch 740/1000 | Loss: 0.0009 | Acc: 62.65%
# Epoch 750/1000 | Loss: 0.0008 | Acc: 63.04%
# Epoch 760/1000 | Loss: 0.0007 | Acc: 62.94%
# Epoch 770/1000 | Loss: 0.0006 | Acc: 62.75%
# Epoch 780/1000 | Loss: 0.0006 | Acc: 62.75%
# Epoch 790/1000 | Loss: 0.0007 | Acc: 63.14%
# Epoch 800/1000 | Loss: 0.0006 | Acc: 63.14%
# Epoch 810/1000 | Loss: 0.0005 | Acc: 63.14%
# Epoch 820/1000 | Loss: 0.0005 | Acc: 63.53%
# Epoch 830/1000 | Loss: 0.0007 | Acc: 63.53%
# Epoch 840/1000 | Loss: 0.0005 | Acc: 63.53%
# Epoch 850/1000 | Loss: 0.0004 | Acc: 63.92%
# Epoch 860/1000 | Loss: 0.0004 | Acc: 64.12%
# Epoch 870/1000 | Loss: 0.0004 | Acc: 64.02%
# Epoch 880/1000 | Loss: 0.0004 | Acc: 63.82%
# Epoch 890/1000 | Loss: 0.0005 | Acc: 63.63%
# Epoch 900/1000 | Loss: 0.0004 | Acc: 63.82%
# Epoch 910/1000 | Loss: 0.0074 | Acc: 63.14%
# Epoch 920/1000 | Loss: 0.0041 | Acc: 63.24%
# Epoch 930/1000 | Loss: 0.0013 | Acc: 62.84%
# Epoch 940/1000 | Loss: 0.0010 | Acc: 63.24%
# Epoch 950/1000 | Loss: 0.0009 | Acc: 63.33%
# Epoch 960/1000 | Loss: 0.0008 | Acc: 63.73%
# Epoch 970/1000 | Loss: 0.0007 | Acc: 63.53%
# Epoch 980/1000 | Loss: 0.0006 | Acc: 63.33%
# Epoch 990/1000 | Loss: 0.0006 | Acc: 63.04%
# Epoch 1000/1000 | Loss: 0.0005 | Acc: 63.53%
#
# Starting MLP2 Probe...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 49
#      47 # --- Experiment 4: Simple MLP Probe (2-layer) ---
#      48 print("\nStarting MLP2 Probe...")
# ---> 49 mlp2_head = MLP(embed_dim, 512, num_classes)
#      50 mlp2_history = train_fast_probe(mlp2_head, fast_train_loader, fast_val_loader, epochs=1000)
#      52 # --- Plot Comparison ---
#      53 # (Your plotting code remains the same!)
#      54 # --- Plot Comparison ---
#
# TypeError: MLP.__init__() takes 3 positional arguments but 4 were given

# %% [markdown]
# ## Evaluate with mlp

# %%
class MLP(nn.Module):
    def __init__(self, dim: int, hidden_dim: int, out_dim: int):
        super().__init__()
        self.fc1 = nn.Linear(dim, hidden_dim)
        self.act = nn.GELU()
        self.fc2 = nn.Linear(hidden_dim, out_dim)

    def forward(self, x):
        return self.fc2(self.act(self.fc1(x)))

# %%
mlp = MLP(512, 256, 128)
epochs = 250
lr = 1e-3
classifier_results = train_classifier(simCLR, mlp, probe_train_loader, probe_val_loader, epochs, lr)

# %%
summary(mae_model)
# Out:
# =====================================================================================
# Layer (type:depth-idx)                                       Param #
# =====================================================================================
# MaskedAutoencoderViT                                         253,440
# ├─PatchEmbed: 1-1                                            --
# │    └─Conv2d: 2-1                                           590,592
# ├─ModuleList: 1-2                                            --
# │    └─TransformerBlock: 2-2                                 --
# │    │    └─LayerNorm: 3-1                                   1,536
# │    │    └─MultiheadAttention: 3-2                          2,362,368
# │    │    └─LayerNorm: 3-3                                   1,536
# │    │    └─MLP: 3-4                                         4,722,432
# │    └─TransformerBlock: 2-3                                 --
# │    │    └─LayerNorm: 3-5                                   1,536
# │    │    └─MultiheadAttention: 3-6                          2,362,368
# │    │    └─LayerNorm: 3-7                                   1,536
# │    │    └─MLP: 3-8                                         4,722,432
# │    └─TransformerBlock: 2-4                                 --
# │    │    └─LayerNorm: 3-9                                   1,536
# │    │    └─MultiheadAttention: 3-10                         2,362,368
# │    │    └─LayerNorm: 3-11                                  1,536
# │    │    └─MLP: 3-12                                        4,722,432
# │    └─TransformerBlock: 2-5                                 --
# │    │    └─LayerNorm: 3-13                                  1,536
# │    │    └─MultiheadAttention: 3-14                         2,362,368
# │    │    └─LayerNorm: 3-15                                  1,536
# │    │    └─MLP: 3-16                                        4,722,432
# │    └─TransformerBlock: 2-6                                 --
# │    │    └─LayerNorm: 3-17                                  1,536
# │    │    └─MultiheadAttention: 3-18                         2,362,368
# │    │    └─LayerNorm: 3-19                                  1,536
# │    │    └─MLP: 3-20                                        4,722,432
# │    └─TransformerBlock: 2-7                                 --
# │    │    └─LayerNorm: 3-21                                  1,536
# │    │    └─MultiheadAttention: 3-22                         2,362,368
# │    │    └─LayerNorm: 3-23                                  1,536
# │    │    └─MLP: 3-24                                        4,722,432
# │    └─TransformerBlock: 2-8                                 --
# │    │    └─LayerNorm: 3-25                                  1,536
# │    │    └─MultiheadAttention: 3-26                         2,362,368
# │    │    └─LayerNorm: 3-27                                  1,536
# │    │    └─MLP: 3-28                                        4,722,432
# │    └─TransformerBlock: 2-9                                 --
# │    │    └─LayerNorm: 3-29                                  1,536
# │    │    └─MultiheadAttention: 3-30                         2,362,368
# │    │    └─LayerNorm: 3-31                                  1,536
# │    │    └─MLP: 3-32                                        4,722,432
# │    └─TransformerBlock: 2-10                                --
# │    │    └─LayerNorm: 3-33                                  1,536
# │    │    └─MultiheadAttention: 3-34                         2,362,368
# │    │    └─LayerNorm: 3-35                                  1,536
# │    │    └─MLP: 3-36                                        4,722,432
# │    └─TransformerBlock: 2-11                                --
# │    │    └─LayerNorm: 3-37                                  1,536
# │    │    └─MultiheadAttention: 3-38                         2,362,368
# │    │    └─LayerNorm: 3-39                                  1,536
# │    │    └─MLP: 3-40                                        4,722,432
# │    └─TransformerBlock: 2-12                                --
# │    │    └─LayerNorm: 3-41                                  1,536
# │    │    └─MultiheadAttention: 3-42                         2,362,368
# │    │    └─LayerNorm: 3-43                                  1,536
# │    │    └─MLP: 3-44                                        4,722,432
# │    └─TransformerBlock: 2-13                                --
# │    │    └─LayerNorm: 3-45                                  1,536
# │    │    └─MultiheadAttention: 3-46                         2,362,368
# │    │    └─LayerNorm: 3-47                                  1,536
# │    │    └─MLP: 3-48                                        4,722,432
# ├─LayerNorm: 1-3                                             1,536
# ├─Linear: 1-4                                                393,728
# ├─ModuleList: 1-5                                            --
# │    └─TransformerBlock: 2-14                                --
# │    │    └─LayerNorm: 3-49                                  1,024
# │    │    └─MultiheadAttention: 3-50                         1,050,624
# │    │    └─LayerNorm: 3-51                                  1,024
# │    │    └─MLP: 3-52                                        2,099,712
# │    └─TransformerBlock: 2-15                                --
# │    │    └─LayerNorm: 3-53                                  1,024
# │    │    └─MultiheadAttention: 3-54                         1,050,624
# │    │    └─LayerNorm: 3-55                                  1,024
# │    │    └─MLP: 3-56                                        2,099,712
# │    └─TransformerBlock: 2-16                                --
# │    │    └─LayerNorm: 3-57                                  1,024
# │    │    └─MultiheadAttention: 3-58                         1,050,624
# │    │    └─LayerNorm: 3-59                                  1,024
# │    │    └─MLP: 3-60                                        2,099,712
# │    └─TransformerBlock: 2-17                                --
# │    │    └─LayerNorm: 3-61                                  1,024
# │    │    └─MultiheadAttention: 3-62                         1,050,624
# │    │    └─LayerNorm: 3-63                                  1,024
# │    │    └─MLP: 3-64                                        2,099,712
# ├─LayerNorm: 1-6                                             1,024
# ├─Linear: 1-7                                                393,984
# =====================================================================================
# Total params: 99,298,304
# Trainable params: 99,046,144
# Non-trainable params: 252,160
# =====================================================================================
