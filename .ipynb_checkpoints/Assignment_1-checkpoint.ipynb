# %%
import torch
import torch.nn.functional as F
import matplotlib.pyplot as plt
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import DataLoader

# %%
dataset = torchvision.datasets.MNIST(
    root='./data',         
    download=True
)

# %%
import torch
import torch.nn.functional as F

def patchify(imgs: torch.Tensor, patch=5, stride=1):
    #input: (B, C, H, W)
    cols = F.unfold(imgs, kernel_size=patch, stride=stride).transpose(1, 2)
    # out: (B, L, 25)  L = number of patches per image
    # Merge (B, L)
    patches = cols.reshape(-1, 25)
    return patches

# %%
images = dataset.data.float() / 255.0
images = images.unsqueeze(1)
patches=patchify(images)

keep = patches.sum(dim=1) > 0
non_blank = patches[keep]
print(non_blank.shape)
# Out:
# torch.Size([20074704, 25])

# %%
# Initialize centroids randomly
centroids = tensor_data[torch.randperm(tensor_data.size(0))[:4]]

# Define the number of iterations
num_iterations = 100

for _ in range(num_iterations):
    # Calculate distances from data points to centroids
    distances = torch.cdist(tensor_data, centroids)

    # Assign each data point to the closest centroid
    _, labels = torch.min(distances, dim=1)

    # Update centroids by taking the mean of data points assigned to each centroid
    for i in range(4):
        if torch.sum(labels == i) > 0:
            centroids[i] = torch.mean(tensor_data[labels == i], dim=0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 # Initialize centroids randomly
# ----> 2 centroids = tensor_data[torch.randperm(tensor_data.size(0))[:4]]
#       4 # Define the number of iterations
#       5 num_iterations = 100
#
# NameError: name 'tensor_data' is not defined

# %%
# Visualize clusters
plt.scatter(data[:, 0], data[:, 1], c=labels.numpy(), cmap='viridis')
plt.scatter(centroids[:, 0], centroids[:, 1], marker='X', s=200, color='red')
plt.show()
